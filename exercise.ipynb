# %% [markdown]
# # "My Jupyter Notebook on IBM Watson Studio"

# %% [markdown]
# **Ebin Thakachan**
#
# Data Analyst

# %% [markdown]
# *I am interested in data science as it is quite fun and challenging to sieve thorgh raw data to get useful results that can help the company prosper.*

# %% [markdown]
# ### "The code below is supposed to subtract 2 numbers"

# %%
5-4
# Out:
# 1

# %% [markdown]
# horizontal rule
#
# ###
#
# Bulleted list
# * Points to note
# * Do remeber
#
# Block quotes
# > Keep learning
# >
# > Bye
#
# Links
#
# The most common search engine is [GOOGLE](https://www.google.com/)
